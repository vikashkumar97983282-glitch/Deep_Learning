# %% [markdown]
# <a href="https://colab.research.google.com/github/vikashkumar97983282-glitch/Deep_Learning/blob/main/simple_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
docs = [
    "I love learning artificial intelligence.",
    "Python is my favorite programming language.",
    "Deep learning helps computers learn from data.",
    "Neural networks can recognize patterns.",
    "Cloud computing makes applications scalable.",
    "I study machine learning every day.",
    "Data science is an exciting field.",
    "Natural language processing understands text.",
    "Practice every day to improve your skills.",
    "Artificial intelligence is changing the world."
]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token='<nothing>')

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index

# %%
tokenizer.document_count

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences

# %%
from keras.utils import pad_sequences

# %%
sequences = pad_sequences(sequences,padding='post')
sequences

# %%
from keras.datasets import imdb
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
(X_train,X_test),(y_train,y_test) = imdb.load_data()

# %%
X_train
# Out:
# array([list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 22665, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 21631, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 31050, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]),
# ...

# %%
len(X_train[1])
# Out:
# 189

# %%
# The X_test variable is currently corrupted, containing non-iterable elements.
# To fix this, please re-run the cell where imdb.load_data() is called (cell ze89Br3dlZZ1)
# to ensure X_train, X_test, y_train, and y_test are in their correct initial formats.
# After reloading the data, the padding can be applied as intended:
# X_train = pad_sequences(X_train, padding="post")
# X_test = pad_sequences(X_test, padding="post")

# %%
# Now that the data is reloaded, apply padding.
X_train = pad_sequences(X_train, padding='post')
X_test = pad_sequences(X_test, padding='post')

# %%
X_train.shape
# Out:
# (25000, 2494)

# %%
X_train[0]
# Out:
# array([ 1, 14, 22, ...,  0,  0,  0], dtype=int32)

# %%
model = Sequential()

model.add(SimpleRNN(32,input_shape=(2500,1),return_sequences=False))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 32)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,121 (4.38 KB)
#  Trainable params: 1,121 (4.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5299/138640146.py in <cell line: 0>()
# ----> 1 model.fit(X_train,y_train,epochs=5,validation_data=(X_test,y_test))
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/optree/ops.py in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     780     leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     781     flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# ...

# %%
print(X_train.dtype)
print(X_test.dtype)
print(y_train.dtype)
print(y_test.dtype)
# Out:
# int32
# int64
# object
# int64

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_encode.py in _unique_python(values, return_inverse, return_counts)
#     179     try:
# --> 180         uniques_set = set(values)
#     181         uniques_set, missing_values = _extract_missing(uniques_set)
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5299/835197552.py in <cell line: 0>()
#       3 encoder = LabelEncoder()
#       4
# ----> 5 y_train = encoder.fit_transform(y_train)
#       6 y_test = encoder.transform(y_test)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py in fit_transform(self, y)
#     109         """
#     110         y = column_or_1d(y, warn=True)
# ...

# %%
y_train.dtype
# Out:
# dtype('O')

# %%
print(type(y_train))
print(y_train.shape)
print(y_train[:5])
# Out:
# <class 'numpy.ndarray'>
# (25000,)
# [list([1, 591, 202, 14, 31, 6, 717, 10, 10, 18142, 10698, 5, 4, 360, 7, 4, 177, 5760, 394, 354, 4, 123, 9, 1035, 1035, 1035, 10, 10, 13, 92, 124, 89, 488, 7944, 100, 28, 1668, 14, 31, 23, 27, 7479, 29, 220, 468, 8, 124, 14, 286, 170, 8, 157, 46, 5, 27, 239, 16, 179, 15387, 38, 32, 25, 7944, 451, 202, 14, 6, 717])
# ...
